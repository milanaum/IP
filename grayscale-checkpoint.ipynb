# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\central computer lab\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\central computer lab\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img=cv2.imread('rose1.jpg',0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('rose1.jpg')
plt.imshow(img)

# %%
import cv2 
from PIL import Image
img=Image.open('rose1.jpg')
img=img.rotate(180)
img.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import ImageColor
img2=ImageColor.getrgb("red")
print(img2)
img1=ImageColor.getrgb("yellow")
print(img1)
img3=ImageColor.getrgb("blue")
print(img3)
# Out:
# (255, 0, 0)
# (255, 255, 0)
# (0, 0, 255)

# %%
from PIL import Image
img=Image.new('RGB',(200,400),(0,0,255))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('rose1.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RG)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\CENTRA~1\AppData\Local\Temp/ipykernel_4316/2094750310.py in <module>
#       5 plt.imshow(img)
#       6 plt.show()
# ----> 7 img=cv2.cvtColor(img,cv2.COLOR_BGR2RG)
#       8 plt.show()
#       9 img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
#
# AttributeError: module 'cv2' has no attribute 'COLOR_BGR2RG'

# %%
from PIL import Image
image=Image.open('rose1.jpg')
print("Filename:",image.filename)
print("Format:",image.format)
print("Mode:",image.mode)
print("Size:",image.size)
print("Width:",image.width)
print("Height:",image.height)
image.close()
# Out:
# Filename: rose1.jpg
# Format: JPEG
# Mode: RGB
# Size: (190, 265)
# Width: 190
# Height: 265
